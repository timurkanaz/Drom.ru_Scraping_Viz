# %%
alert_freq=10 # How frequent messages should appear
n_proxies=8 # Number of proxies
multiplicator=7 # Number of threads for each proxy ip
pause=7 # How much time to sleep
threads_models=4

# %%
proxies=["http://login:password@ip:port"
,"http://login:password@ip:port"
,"http://login:password@ip:port"
,"http://login:password@ip:port"
,"http://login:password@ip:port"
,"http://login:password@ip:port"
,"http://login:password@ip:port"
,"http://login:password@ip:port"]
proxies_dict=proxies*multiplicator
proxies_dict=[{'https':i} for i in proxies_dict]

# %%
import requests as r
import pandas as pd
from IPython.display import clear_output
from bs4 import BeautifulSoup
import time
import random
import urllib3
import urllib
import os
import shutil
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
import re
from numpy import random, array_split
from multiprocessing.pool import ThreadPool


desktop_agents = ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/602.2.14 (KHTML, like Gecko) Version/10.0.1 Safari/602.2.14',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'
                 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.135 YaBrowser/21.6.3.757 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.164 YaBrowser/21.6.4.786 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 OPR/74.0.3911.107',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.2 Safari/605.1.15',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.18 Safari/537.36 OPR/55.0.2962.0 (Edition developer)',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.152 YaBrowser/21.2.2.102 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.135 YaBrowser/21.6.2.855 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 YaBrowser/20.12.3.138 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 YaBrowser/20.8.3.112 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3343.4 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.170 Safari/537.36 OPR/53.0.2907.68',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0.2 Safari/605.1.15',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 YaBrowser/20.8.2.92 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36 OPR/73.0.3856.344',
                 'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201',
                 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:59.0) Gecko/20100101 Firefox/59.0',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 OPR/74.0.3911.160',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36 Edg/87.0.664.60',
                 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.101 YaBrowser/20.7.0.899 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; ) AppleWebKit/53']

# %%
def beautiful_html(resp):
    return BeautifulSoup(resp.text,"html.parser")

# %%
def get_regions():
    u=0
    while u==0:
        try:
            raw_data=r.get("https://www.drom.ru/my_region/",proxies=urllib.request.getproxies(),headers={"User-Agent":random.choice(desktop_agents)},verify=False)
            data=beautiful_html(raw_data)
            regions=[]
            for link in data.find_all('a',{'class':'b-link regionLink'},href=True):
                regions.append((link.text.strip(),re.search('=(.+)',link['href']).group(1)))
            u=1
        except:
            time.sleep(60)            
    print("Регионы собраны")
    return regions

# %%
def get_models(tuples):
    print(f"Info about models in all regions. Thread {tuples[0]}")
    model_hrefs=[]
    with r.Session() as s:
        for tup in tuples[1]:
            to=0
            u=0
            length=0
            while u==0:
                try:
                    raw_data=s.get(f"https://auto.drom.ru/region{int(tup[1])}/?grouping=1&ph=1&unsold=1#tabs",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                    data=beautiful_html(raw_data)
                    if raw_data.reason=='OK': 
                        distinct_models=int(re.findall('.+?(?=модел)',data.find_all('a',{"href":f"https://auto.drom.ru/region{int(tup[1])}/?grouping=1&ph=1&unsold=1#tabs"})[0].text.replace('\xa0',u' '))[0].replace(' ',''))
                        number_of_pages=distinct_models//20
                        if  (distinct_models - number_of_pages*20)>0:
                            number_of_pages+=1
                        u=1
                    else:
                        print(f"Thread-{tuples[0]},{tup[1]},не подходящий ответ")
                        to+=1
                        if to%150==0:
                            time.sleep(7)
                        else:
                            time.sleep(3)
                   
                except:
                    print(f"Thread-{tuples[0]}, {tup[1]} ,не удался get запрос")
                    to+=1
                    if to%150==0:
                        time.sleep(7)
                    else:
                        time.sleep(3)
            page=1
            to=0
            try:
                while page<=number_of_pages:
                    u=0
                    while u==0:
                        try:
                            raw_data=s.get(f"https://auto.drom.ru/region{int(tup[1])}/page{int(page)}/?grouping=1&ph=1&unsold=1",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                            data=beautiful_html(raw_data)
                            if len(data.find_all('div',{"data-app-root":"bulls-list-models-range"})[0].find_all('a',{'class':"css-ew3ldr e13zubtn5"},href=True))==0:  #Class is changing
                                to+=1
                                print(f"Thread-{tuples[0]} , {f'https://auto.drom.ru/region{int(tup[1])}/page{int(page)}/?grouping=1&ph=1&unsold=1'} ,нет ссылок")
                                if to%150==0:
                                    time.sleep(7)
                                else:
                                    time.sleep(3)
                            else:
                               
                                u=1
                        except:
                            print(f"Thread-{tuples[0]} , {f'https://auto.drom.ru/region{int(tup[1])}/page{int(page)}/?grouping=1&ph=1&unsold=1'} ,не удался get запрос")
                            to+=1
                            if to%150==0:
                                time.sleep(7)
                            else:
                                time.sleep(3)
                    hrefs=[(i['href'],re.findall('.+?(?=,)',i.text)[0],tup[0],tup[1]) for i in data.find_all('div',{"data-app-root":"bulls-list-models-range"})[0].find_all('a',{'class':"css-ew3ldr e13zubtn5"},href=True)] #Class is changing
                    for val in hrefs:
                        model_hrefs.append(val)
                    length+=len(hrefs)
                    page+=1
                print(f"{tup[1]},{tup[0]},pages: {number_of_pages}  models: {length} ")
            except:
                print(f"Thread-{tuples[0]} , {tup[0]} ,не удалось перейти по ссылке")
                print(f"{tup[1]},{tup[0]}")
    model_hrefs=set(model_hrefs)
    return model_hrefs

# %%
def get_ad_info(tuples,s):
    #print(f"Collecting all ads hrefs.Thread {tuples[0]}")
    ads_info=[]
    for ind,tup in enumerate(tuples[1]):
        u=0
        to=0
        region_code=tup[-1]
        region=tup[-2]
        model=tup[-3]
        while u==0:
            try:
                raw_data=s.get(f"{tup[0]}",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                data=beautiful_html(raw_data)
                if 'Запрошенная вами страница не существует!' in raw_data.text:
                    break
                elif 'Подать объявление' not in raw_data.text:
                    raise Exception   
                elif len([i.text.replace("\xa0"," ") for i in data.find_all("table",{"class":"css-xalqz7 eo7fo180"})[0].find_all("td",{"class":"css-1azz3as eka0pcn0"})])>0: 
                    u=1
                else:
                    to+=1
                    if to%150==0:
                        time.sleep(pause*3)
                        print(f"{tup[0]} - не пройденных запросов : {to} ")
                    else:
                        time.sleep(pause)
            except:
                to+=1
                if to%150==0:
                    time.sleep(pause*3)
                    print(f"{tup[0]} - не пройденных запросов : {to} ")
                else:
                    time.sleep(pause)
            
        p=0
        try:
            l2=[i.text.replace("\xa0"," ") for i in data.find_all("table",{"class":"css-xalqz7 eo7fo180"})[0].find_all('th',{'class':'css-1dzcqnh eka0pcn1'})] #All classes are changing!
            l1=[i.text.replace("\xa0"," ") for i in data.find_all("table",{"class":"css-xalqz7 eo7fo180"})[0].find_all('td',{'class':'css-1azz3as eka0pcn0'})] #All classes are changing!
        except:
            print(f"{tup[0]} - невалидная ссылка. {raw_data.reason}")
#                print(raw_data.text)
#                print(raw_data)
#                print(data)
            p=1
        if p==0:
            dct=dict(zip(l2,l1))
            city=data.find_all("div",{"class":"css-inmjwf e162wx9x0"})[-1].text
            idd=re.search("\/(\d+).html",tup[0]).group(1)
            ads_info.append((region,model,region_code,idd,city,dct))
        #print(f"Thread: {tuples[0]}, {ind+1}/{len(tuples[1])}")
    return ads_info
# Out:
# <>:48: SyntaxWarning: invalid escape sequence '\/'
# <>:48: SyntaxWarning: invalid escape sequence '\/'
# C:\Users\timna\AppData\Local\Temp\ipykernel_26568\4179076251.py:48: SyntaxWarning: invalid escape sequence '\/'
#   idd=re.search("\/(\d+).html",tup[0]).group(1)

# %%
def models_exists(data):
    try:
        k=re.findall(".+?(?= объяв)",data.find_all("div",{"class":"css-1xkq48l eckkbc90"})[0].text)[0].replace('\xa0',u' ').replace(' ','') #Class is changing!
        return 1
    except:
        return -1

# %%
def get_ads_hrefs(tuples):
    #print(f"Collecting all ads hrefs.Thread {tuples[0]}")
    region=[]
    model=[]
    region_code=[]
    idc=[]
    city=[]
    engine=[]
    power=[]
    transmission=[]
    drive=[]
    body_type=[]
    color=[]
    mileage=[]
    swheel=[]
    
    dupl=0
    with r.Session() as s:
        s.proxies=tuples[2]
        for ind,tup in enumerate(tuples[1]):
            if (ind+1)%alert_freq==0:
                print(f"Обработка {tup[0]}, Thread: {tuples[0]}")
            to=0
            u=0
            length=0
            while u==0:
                try:
                    raw_data=s.get(f"{tup[0]}",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                    data=beautiful_html(raw_data)
                    p=models_exists(data)
                    if ('Запрошенная вами страница не существует!' in raw_data.text):
                        number_of_pages=0
                        break
                    if raw_data.reason=='OK' and p==1: 
                        distinct_ads=int(re.findall(".+?(?= объяв)",data.find_all("div",{"class":"css-nlq3fc edzrckn0","id":"tabs"})[0].text)[0].replace('\xa0',u' ').replace(' ',''))
                        number_of_pages=distinct_ads//20
                        if  (distinct_ads - number_of_pages*20)>0:
                            number_of_pages+=1
                        u=1
                    elif 'Подать объявление' not in raw_data.text:
                        raise Exception
                    elif p==-1:
                        number_of_pages=0
                        break
                    else:
                        to+=1
                        if to%150==0:
                            print(f"{tup[0]} не пройденных запросов : {to} ")
                            time.sleep(pause*3)
                        else:
                            time.sleep(pause)
                except:
                    to+=1
                    if to%150==0:
                        print(f"{tup[0]} не пройденных запросов : {to} ")
                        time.sleep(pause*3)
                    else:
                        time.sleep(pause)
            u=0
            page=1
            to=0
            try:
                while page<=number_of_pages:
                    u=0
                    while u==0:
                        try:
                            raw_data=s.get(f"{tup[0].replace('?ph=1&unsold=1','')}page{page}/?unsold=1&ph=1",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                            data=beautiful_html(raw_data)
                            m=models_exists(data)
                            if ('Запрошенная вами страница не существует!' in raw_data.text):
                                break
                            elif 'Подать объявление' not in raw_data.text:
                                raise Exception
                            elif m==-1:
                                break
                            else:
                                u=1
                        except:
                            to+=1
                            if to%150==0:
                                time.sleep(pause*3)
                                print(f"{tup[0].replace('?ph=1&unsold=1','')}page{page}/?unsold=1&ph=1 - не пройденных запросов: {to}")
                            else:
                                time.sleep(pause)
                    if m==1:
                        hrefs=[(i['href'],tup[0],tup[1],tup[2],tup[3]) for i in data.find_all("div",{"data-bulletin-list":"true"})[0].find_all("a",{"class":"g6gv8w4 g6gv8w8 _1ioeqy90"})] #Class of 'a' element is changing!
                        length+=len(hrefs)
                        for val in hrefs:
                            i=(val,get_ad_info((1,[val]),s))
                            if dupl==0:
                                try:
                                    region.append(i[1][0][0])
                                except:
                                    region.append('No info')
                                try:
                                    model.append(i[1][0][1])
                                except:
                                    model.append('No info')
                                try:
                                    region_code.append(i[1][0][2])
                                except:
                                    region_code.append('No info')
                                try:
                                    idc.append(i[1][0][3])
                                except:
                                    idc.append('No info')
                                try:
                                    city.append(i[1][0][4])
                                except:
                                    city.append('No info')
                                try:
                                    engine.append(i[1][0][5]['Двигатель'])
                                except:
                                    engine.append('No info')
                                try:
                                    power.append(i[1][0][5]['Мощность'])
                                except:
                                    power.append('No info')
                                try:
                                    transmission.append(i[1][0][5]['Коробка передач'])
                                except:
                                    transmission.append('No info')
                                try:
                                    drive.append(i[1][0][5]['Привод'])
                                except:
                                    drive.append('No info')
                                try:
                                    body_type.append(i[1][0][5]['Тип кузова'])
                                except:
                                    body_type.append('No info')
                                try:
                                    color.append(i[1][0][5]['Цвет'])
                                except:
                                    color.append('No info')
                                try:
                                    mileage.append(i[1][0][5]['Пробег'])
                                except:
                                    mileage.append('No info')
                                try:
                                    swheel.append(i[1][0][5]['Руль'])
                                except:
                                    swheel.append('No info')
                            else:
                                pass
                    page+=1
                if (ind+1)%alert_freq==0:
                    print(f"Thread:{tuples[0]} {ind+1}/{len(tuples[1])}, {tup[0]} , {tup[1]}, {tup[2]} , pages: {number_of_pages}  ads:{length} ")
            except:
                print(f"Thread:{tuples[0]} {ind+1}/{len(tuples[1])}")
                pass
    return pd.DataFrame([idc,region,region_code,city,model,body_type,color,swheel,mileage,engine,power,transmission,drive]).T

# %%
def extract_city(city):
    try:
        return re.findall('Город:([-\sа-яА-Я\d]+)',city)[0].strip()
    except:
        return city
    
def extract_brand(name):
    try:
        return re.findall('^([А-Яа-яA-Za-z]+)',name)[0].replace('Great','Great Wall')
    except:
        return name

def extract_mileage(mil):
    try:
        return int(re.findall('([\s0-9]+) км',mil)[0].replace(' ',''))
    except:
        return mil
    
def extract_HP(val):
    try:
        return int(re.findall('([0-9]+) л.с.,',val)[0])
    except:
        return val

def correct_errors(val):
    if val=='Iran':
        return 'Iran Khodro'
    elif val=='KG':
        return 'KG Mobility'
    elif val=='Land':
        return 'Land Rover'
    elif val=='M':
        return 'M-Hero'
    elif val=='No':
        return 'No info'
    elif val=='Rolls':
        return 'Rolls Royce'
    else:
        return val
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\timna\AppData\Local\Temp\ipykernel_26568\122939278.py:3: SyntaxWarning: invalid escape sequence '\s'
#   return re.findall('Город:([-\sа-яА-Я\d]+)',city)[0].strip()
# C:\Users\timna\AppData\Local\Temp\ipykernel_26568\122939278.py:15: SyntaxWarning: invalid escape sequence '\s'
#   return int(re.findall('([\s0-9]+) км',mil)[0].replace(' ',''))

# %%
def Drom_Parser():
    regs=get_regions()
    rows_divided=list(array_split(regs,threads_models))
    nums_models=[i+1 for i in range(threads_models)]
    rd=list(zip(nums_models,rows_divided))
    pool=ThreadPool(threads_models)
    l=pool.map(get_models,rd)
    hrefs=[]
    for val in l:
        for val_val in val:
            hrefs.append(val_val) 
    threads_ads=n_proxies*multiplicator
    rows_divided=list(array_split(hrefs,threads_ads))
    nums_ads=[i+1 for i in range(threads_ads)]
    hd=list(zip(nums_ads,rows_divided,proxies_dict))
    pool=ThreadPool(threads_ads)
    time.sleep(150)
    l=pool.map(get_ads_hrefs,hd)
    df=pd.concat(l)
    print('Предобработка данных')
    df.columns=['ID','Region','Region code','City','Model','Body type','Color','Steering wheel','Mileage','Engine','Horse power','Transmission','Drive']
    df['City']=df['City'].map(lambda x:extract_city(x))
    df['Brand']=df.Model.map(lambda x:extract_brand(x))
    df['Brand']=df.Brand.map(lambda x:correct_errors(x))
    df['Mileage']=df.Mileage.map(lambda x:extract_mileage(x))
    df['Horse power']=df['Horse power'].map(lambda x:extract_HP(x))
    df.drop_duplicates(subset=['ID'],keep='last',inplace=True)
    print('Сохранение')
    df.to_excel("Drom_Scraping_Results.xlsx",sheet_name='Drom Scraping Results',index=False)

# %%
Drom_Parser()
# Out:
# Регионы собраны
# Info about models in all regions. Thread 1
# Info about models in all regions. Thread 2
# Info about models in all regions. Thread 3
# Info about models in all regions. Thread 4
# Thread-3 , https://auto.drom.ru/region60/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region22/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region44/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region78/page7/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region22/page5/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region44/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region22/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 60,Псковская область,pages: 14  models: 277
# 44,Костромская область,pages: 12  models: 235
# 1,Республика Адыгея,pages: 13  models: 249
# Thread-1 , https://auto.drom.ru/region22/page15/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region22/page15/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region22/page17/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region4/page13/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region23/page28/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region23/page30/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 4,Республика Алтай,pages: 24  models: 472
# Thread-2 , https://auto.drom.ru/region23/page35/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 78,Санкт-Петербург,pages: 58  models: 1155
# Thread-3 , https://auto.drom.ru/region2/page17/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 22,Алтайский край,pages: 57  models: 1121
# 64,Саратовская область,pages: 25  models: 497
# Thread-3 , https://auto.drom.ru/region2/page29/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region65/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region23/page71/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 2,Республика Башкортостан,pages: 43  models: 858
# Thread-4 , https://auto.drom.ru/region65/page14/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 23,Краснодарский край,pages: 76  models: 1503
# 65,Сахалинская область,pages: 20  models: 382
# Thread-3 , https://auto.drom.ru/region3/page11/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 28,Амурская область,pages: 40  models: 792
# Thread-2 , https://auto.drom.ru/region24/page19/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region24/page29/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region66/page26/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 29,Архангельская область,pages: 16  models: 319
# 3,Республика Бурятия,pages: 39  models: 776
# Thread-3 , https://auto.drom.ru/region5/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region24/page39/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 30,Астраханская область,pages: 22  models: 438
# Thread-3 , https://auto.drom.ru/region5/page14/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region24/page45/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 5,Республика Дагестан,pages: 21  models: 420
# Thread-4 , https://auto.drom.ru/region66/page59/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 6,Республика Ингушетия,pages: 9  models: 167
# 31,Белгородская область,pages: 21  models: 409
# 66,Свердловская область,pages: 60  models: 1194
# 8,Республика Калмыкия,pages: 3  models: 54
# 24,Красноярский край,pages: 62  models: 1222
# Thread-4 , https://auto.drom.ru/region67/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region10/page1/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region67/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 32,Брянская область,pages: 19  models: 366
# 10,Республика Карелия,pages: 15  models: 299
# Thread-2 , https://auto.drom.ru/region45/page17/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 67,Смоленская область,pages: 16  models: 314
# Thread-1 , https://auto.drom.ru/region33/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 11,Республика Коми,pages: 13  models: 251
# 45,Курганская область,pages: 33  models: 660
# 33,Владимирская область,pages: 19  models: 380
# Thread-4 , https://auto.drom.ru/region26/page31/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 46,Курская область,pages: 16  models: 312
# 26,Ставропольский край,pages: 36  models: 708
# 47,Ленинградская область,pages: 13  models: 251
# 34,Волгоградская область,pages: 31  models: 608
# Thread-4 , https://auto.drom.ru/region68/page11/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region68/page12/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region35/page12/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 102,Республика Крым,pages: 51  models: 1011
# 68,Тамбовская область,pages: 15  models: 297
# Thread-4, 69 ,не удался get запрос
# 48,Липецкая область,pages: 18  models: 350
# Thread-3 , https://auto.drom.ru/region12/page7/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region69/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 35,Вологодская область,pages: 21  models: 411
# Thread-1 , https://auto.drom.ru/region36/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 12,Республика Марий Эл,pages: 11  models: 209
# Thread-3 , https://auto.drom.ru/region13/page1/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 49,Магаданская область,pages: 18  models: 349
# Thread-2 , https://auto.drom.ru/region77/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region36/page15/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 69,Тверская область,pages: 22  models: 425
# 13,Республика Мордовия,pages: 14  models: 280
# Thread-4 , https://auto.drom.ru/region70/page10/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region77/page12/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region14/page7/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 36,Воронежская область,pages: 35  models: 694
# Thread-2 , https://auto.drom.ru/region77/page23/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 14,Республика Саха (Якутия),pages: 28  models: 548
# 79,Еврейская автономная область,pages: 15  models: 295
# Thread-3 , https://auto.drom.ru/region15/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region77/page35/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region101/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 70,Томская область,pages: 47  models: 921
# 15,Республика Северная Осетия,pages: 13  models: 247
# Thread-2 , https://auto.drom.ru/region77/page40/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region101/page18/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region77/page53/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region71/page23/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 71,Тульская область,pages: 24  models: 464
# 101,Забайкальский край,pages: 41  models: 811
# 16,Республика Татарстан,pages: 42  models: 821
# 77,Москва,pages: 76  models: 1506
# 37,Ивановская область,pages: 17  models: 321
# Thread-2 , https://auto.drom.ru/region50/page10/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region72/page32/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 17,Республика Тыва,pages: 20  models: 395
# Thread-2 , https://auto.drom.ru/region50/page18/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region38/page26/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region50/page25/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 72,Тюменская область,pages: 58  models: 1154
# Thread-1 , https://auto.drom.ru/region38/page38/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region19/page31/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region50/page40/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region18/page15/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region38/page49/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region19/page39/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 19,Республика Хакасия,pages: 42  models: 821
# 50,Московская область,pages: 53  models: 1055
# 18,Удмуртская Республика,pages: 27  models: 529
# Thread-4 , https://auto.drom.ru/region73/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 38,Иркутская область,pages: 64  models: 1263
# Thread-3 , https://auto.drom.ru/region61/page11/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region51/page9/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 7,Кабардино-Балкарская Республика,pages: 10  models: 198
# 51,Мурманская область,pages: 17  models: 322
# Thread-4 , https://auto.drom.ru/region73/page16/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 83,Ненецкий автономный округ,pages: 1  models: 11
# 73,Ульяновская область,pages: 21  models: 409
# Thread-1 , https://auto.drom.ru/region39/page14/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region52/page10/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region39/page17/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 39,Калининградская область,pages: 21  models: 408
# Thread-4 , https://auto.drom.ru/region27/page17/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 61,Ростовская область,pages: 50  models: 981
# Thread-3 , https://auto.drom.ru/region62/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region62/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 52,Нижегородская область,pages: 35  models: 695
# 40,Калужская область,pages: 21  models: 407
# Thread-2 , https://auto.drom.ru/region53/page9/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 62,Рязанская область,pages: 20  models: 384
# Thread-3, 63 ,не удался get запрос
# 53,Новгородская область,pages: 12  models: 228
# Thread-3 , https://auto.drom.ru/region63/page1/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 27,Хабаровский край,pages: 47  models: 927
# 41,Камчатский край,pages: 23  models: 458
# Thread-4 , https://auto.drom.ru/region86/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 9,Карачаево-Черкесская Республика,pages: 7  models: 127
# Thread-2 , https://auto.drom.ru/region54/page18/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region42/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region42/page14/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 63,Самарская область,pages: 36  models: 705
# Thread-4 , https://auto.drom.ru/region86/page38/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region86/page46/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region42/page36/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 86,Ханты-Мансийский автономный округ,pages: 48  models: 958
# Thread-1 , https://auto.drom.ru/region42/page41/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 54,Новосибирская область,pages: 72  models: 1428
# 42,Кемеровская область,pages: 58  models: 1145
# Thread-2 , https://auto.drom.ru/region55/page22/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region43/page9/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region55/page38/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 43,Кировская область,pages: 25  models: 484
# 74,Челябинская область,pages: 55  models: 1083
# 20,Чеченская Республика,pages: 13  models: 245
# 55,Омская область,pages: 53  models: 1054
# 21,Чувашская Республика,pages: 19  models: 367
# 87,Чукотский автономный округ,pages: 1  models: 7
# 56,Оренбургская область,pages: 30  models: 599
# 57,Орловская область,pages: 11  models: 216
# 89,Ямало-Ненецкий автономный округ,pages: 28  models: 546
# Thread-4 , https://auto.drom.ru/region76/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 58,Пензенская область,pages: 17  models: 339
# 76,Ярославская область,pages: 25  models: 486
# Thread-2 , https://auto.drom.ru/region59/page22/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 59,Пермский край,pages: 38  models: 748
# Thread-2 , https://auto.drom.ru/region25/page52/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region25/page55/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 25,Приморский край,pages: 61  models: 1217
# Обработка https://auto.drom.ru/region73/changan/eado_plus/?ph=1&unsold=1, Thread: 55
# Обработка https://auto.drom.ru/region57/nissan/note/?ph=1&unsold=1, Thread: 26
# Обработка https://auto.drom.ru/region59/mercedes-benz/b-class/?ph=1&unsold=1, Thread: 27
# Thread:55 10/875, https://auto.drom.ru/region73/changan/eado_plus/?ph=1&unsold=1 , Changan Eado Plus, Ульяновская область , pages: 1  ads:10
# Обработка https://auto.drom.ru/region102/honda/freed_spike/?ph=1&unsold=1, Thread: 41
# Обработка https://auto.drom.ru/region53/audi/100/?ph=1&unsold=1, Thread: 21
# Thread:26 10/876, https://auto.drom.ru/region57/nissan/note/?ph=1&unsold=1 , Nissan Note, Орловская область , pages: 1  ads:2
# Обработка https://auto.drom.ru/region71/lada/2101/?ph=1&unsold=1, Thread: 44
# Thread:41 10/876, https://auto.drom.ru/region102/honda/freed_spike/?ph=1&unsold=1 , Honda Freed Spike, Республика Крым , pages: 1  ads:2
# Thread:21 10/876, https://auto.drom.ru/region53/audi/100/?ph=1&unsold=1 , Audi 100, Новгородская область , pages: 1  ads:1 Thread:27 10/876, https://auto.drom.ru/region59/mercedes-benz/b-class/?ph=1&unsold=1 , Mercedes-Benz B-Class, Пермский край , pages: 1  ads:3
#
# Обработка https://auto.drom.ru/region78/changan/uni-k/?ph=1&unsold=1, Thread: 47
# Обработка https://auto.drom.ru/region14/bmw/2-series_active_tourer/?ph=1&unsold=1, Thread: 31
# Thread:44 10/876, https://auto.drom.ru/region71/lada/2101/?ph=1&unsold=1 , Лада 2101, Тульская область , pages: 1  ads:3
# Обработка https://auto.drom.ru/region24/volvo/v60/?ph=1&unsold=1, Thread: 19
# Обработка https://auto.drom.ru/region78/cadillac/bls/?ph=1&unsold=1, Thread: 48
# Обработка https://auto.drom.ru/region59/zeekr/x/?ph=1&unsold=1, Thread: 16
# Обработка https://auto.drom.ru/region69/hyundai/getz/?ph=1&unsold=1, Thread: 54
# Thread:31 10/876, https://auto.drom.ru/region14/bmw/2-series_active_tourer/?ph=1&unsold=1 , BMW 2-Series Active Tourer, Республика Саха (Якутия) , pages: 1  ads:3
# Thread:48 10/876, https://auto.drom.ru/region78/cadillac/bls/?ph=1&unsold=1 , Cadillac BLS, Санкт-Петербург , pages: 1  ads:1
# Thread:19 10/876, https://auto.drom.ru/region24/volvo/v60/?ph=1&unsold=1 , Volvo V60, Красноярский край , pages: 1  ads:3
# Обработка https://auto.drom.ru/region16/chery/tiggo/?ph=1&unsold=1, Thread: 35
# Обработка https://auto.drom.ru/region16/infiniti/qx70/?ph=1&unsold=1, Thread: 32
# Обработка https://auto.drom.ru/region28/mazda/mazda6/?ph=1&unsold=1, Thread: 14
# Обработка https://auto.drom.ru/region61/lexus/gs450h/?ph=1&unsold=1, Thread: 34
# Thread:16 10/876, https://auto.drom.ru/region59/zeekr/x/?ph=1&unsold=1 , Zeekr X, Пермский край , pages: 1  ads:1
# Обработка https://auto.drom.ru/region71/lada/niva_travel/?ph=1&unsold=1, Thread: 51
# Обработка https://auto.drom.ru/region102/chery/tiggo_3/?ph=1&unsold=1, Thread: 39
# Thread:34 10/876, https://auto.drom.ru/region61/lexus/gs450h/?ph=1&unsold=1 , Lexus GS450h, Ростовская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/
область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region61/li/l9/?ph=1&unsold=1, Thread: 36
# Обработка https://auto.drom.ru/region72/changan/uni-z/?ph=1&unsold=1, Thread: 54
# Thread:38 10/876, https://auto.drom.ru/region15/mercedes-benz/s-class/?ph=1&unsold=1 , Mercedes-Benz S-Class, Республика Северная Осетия , pages: 1  ads:12
# Thread:54 20/875, https://auto.drom.ru/region72/changan/uni-z/?ph=1&unsold=1 , Changan UNI-Z, Тюменская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region86/dodge/intrepid/?ph=1&unsold=1, Thread: 44
# Thread:36 10/876, https://auto.drom.ru/region61/li/l9/?ph=1&unsold=1 , Li L9, Ростовская область , pages: 1  ads:3
# Thread:44 20/876, https://auto.drom.ru/region86/dodge/intrepid/?ph=1&unsold=1 , Dodge Intrepid, Ханты-Мансийский автономный округ , pages: 1  ads:3
# Thread:51 10/875, https://auto.drom.ru/region71/lada/niva_travel/?ph=1&unsold=1 , Лада Нива Тревел, Тульская область , pages: 4  ads:62
# Обработка https://auto.drom.ru/region86/renault/kaptur/?ph=1&unsold=1, Thread: 50
# Обработка https://auto.drom.ru/region77/toyota/porte/?ph=1&unsold=1, Thread: 22
# Обработка https://auto.drom.ru/region77/nissan/juke/?ph=1&unsold=1, Thread: 21
# Обработка https://auto.drom.ru/region45/volvo/s60/?ph=1&unsold=1, Thread: 24
# Thread:22 10/876, https://auto.drom.ru/region77/toyota/porte/?ph=1&unsold=1 , Toyota Porte, Москва , pages: 1  ads:2
# Обработка https://auto.drom.ru/region41/toyota/corolla_runx/?ph=1&unsold=1, Thread: 3
# Thread:32 20/876, https://auto.drom.ru/region14/toyota/ist/?ph=1&unsold=1 , Toyota ist, Республика Саха (Якутия) , pages: 2  ads:28
# Thread:24 10/876, https://auto.drom.ru/region45/volvo/s60/?ph=1&unsold=1 , Volvo S60, Курганская область , pages: 1  ads:2
# Thread:3 10/876, https://auto.drom.ru/region41/toyota/corolla_runx/?ph=1&unsold=1 , Toyota Corolla Runx, Камчатский край , pages: 1  ads:2
# Обработка https://auto.drom.ru/region28/nissan/liberta_villa/?ph=1&unsold=1, Thread: 14
# Обработка https://auto.drom.ru/region39/opel/vivaro/?ph=1&unsold=1, Thread: 1
# Обработка https://auto.drom.ru/region102/citroen/c4_aircross/?ph=1&unsold=1, Thread: 33
# Thread:14 20/876, https://auto.drom.ru/region28/nissan/liberta_villa/?ph=1&unsold=1 , Nissan Liberta Villa, Амурская область , pages: 1  ads:1
# Thread:1 20/876, https://auto.drom.ru/region39/opel/vivaro/?ph=1&unsold=1 , Opel Vivaro, Калининградская область , pages: 1  ads:1
# Thread:33 10/876, https://auto.drom.ru/region102/citroen/c4_aircross/?ph=1&unsold=1 , Citroen C4 Aircross, Республика Крым , pages: 1  ads:1
# Обработка https://auto.drom.ru/region1/lada/aura/?ph=1&unsold=1, Thread: 40
# Обработка https://auto.drom.ru/region101/changan/eado_plus/?ph=1&unsold=1, Thread: 5
# Обработка https://auto.drom.ru/region71/chery/tiggo_8_pro_max/?ph=1&unsold=1, Thread: 46
# Обработка https://auto.drom.ru/region77/lada/21099/?ph=1&unsold=1, Thread: 26
# Обработка https://auto.drom.ru/region29/lada/2104/?ph=1&unsold=1, Thread: 9
# Thread:40 20/876, https://auto.drom.ru/region1/lada/aura/?ph=1&unsold=1 , Лада Аура, Республика Адыгея , pages: 1  ads:1
# Thread:5 20/876, https://auto.drom.ru/region101/changan/eado_plus/?ph=1&unsold=1 , Changan Eado Plus, Забайкальский край , pages: 1  ads:1
# Обработка https://auto.drom.ru/region17/honda/stepwgn/?ph=1&unsold=1, Thread: 39
# Обработка https://auto.drom.ru/region25/nissan/adwagon/?ph=1&unsold=1, Thread: 20
# Thread:9 10/876, https://auto.drom.ru/region29/lada/2104/?ph=1&unsold=1 , Лада 2104, Архангельская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region23/suzuki/landy/?ph=1&unsold=1, Thread: 16
# Обработка https://auto.drom.ru/region39/bmw/x7/?ph=1&unsold=1, Thread: 7
# Thread:50 10/875, https://auto.drom.ru/region86/renault/kaptur/?ph=1&unsold=1 , Renault Kaptur, Ханты-Мансийский автономный округ , pages: 2  ads:28
# Обработка https://auto.drom.ru/region19/chevrolet/tahoe/?ph=1&unsold=1, Thread: 37
# Thread:7 20/876, https://auto.drom.ru/region39/bmw/x7/?ph=1&unsold=1 , BMW X7, Калининградская область , pages: 1  ads:1
# Thread:56 10/875, https://auto.drom.ru/region18/kia/rio/?ph=1&unsold=1 , Kia Rio, Удмуртская Республика , pages: 5  ads:86
# Thread:16 20/876, https://auto.drom.ru/region23/suzuki/landy/?ph=1&unsold=1 , Suzuki Landy, Краснодарский край , pages: 1  ads:3
# Thread:37 20/876, https://auto.drom.ru/region19/chevrolet/tahoe/?ph=1&unsold=1 , Chevrolet Tahoe, Республика Хакасия , pages: 1  ads:1
# Обработка https://auto.drom.ru/region63/haval/dargo/?ph=1&unsold=1, Thread: 42
# Обработка https://auto.drom.ru/region18/mitsubishi/outlander/?ph=1&unsold=1, Thread: 43
# Обработка https://auto.drom.ru/region56/volvo/c30/?ph=1&unsold=1, Thread: 15
# Обработка https://auto.drom.ru/region11/renault/megane/?ph=1&unsold=1, Thread: 34
# Обработка https://auto.drom.ru/region72/geely/ck/?ph=1&unsold=1, Thread: 52
# Thread:15 20/876, https://auto.drom.ru/region56/volvo/c30/?ph=1&unsold=1 , Volvo C30, Оренбургская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region74/honda/civic_ferio/?ph=1&unsold=1, Thread: 48
# Обработка https://auto.drom.ru/region10/lada/2113/?ph=1&unsold=1, Thread: 33
# Обработка https://auto.drom.ru/region61/lexus/tx350/?ph=1&unsold=1, Thread: 32
# Thread:33 20/876, https://auto.drom.ru/region10/lada/2113/?ph=1&unsold=1 , Лада 2113 Самара, Республика Карелия , pages: 1  ads:1
# https://auto.drom.ru/voronezh/skoda/octavia/855625869.html - не пройденных запросов : 150
# https://auto.drom.ru/togliatti/haval/dargo/934566639.html - не пройденных запросов : 150
# https://auto.drom.ru/nizhniy-tagil/rover/75/212841649.html - не пройденных запросов : 150
# https://auto.drom.ru/cherkessk/toyota/camry/663416379.html - не пройденных запросов : 150
# https://auto.drom.ru/moscow/lada/21099/320071250.html - не пройденных запросов : 150
# https://auto.drom.ru/syktyvkar/renault/megane/105267441.html - не пройденных запросов : 150
# https://auto.drom.ru/sochi/geely/gs/870727400.html - не пройденных запросов : 150
# https://auto.drom.ru/yakutsk/volkswagen/polo/51577564.html - не пройденных запросов : 150
# https://auto.drom.ru/moscow/renault/sandero/791633435.html - не пройденных запросов : 150
# https://auto.drom.ru/izhevsk/mitsubishi/outlander/697394309.html - не пройденных запросов : 150
# https://auto.drom.ru/kemerovo/toyota/land_cruiser_prado/757557298.html - не пройденных запросов : 150
# https://auto.drom.ru/syktyvkar/lifan/breez/661101903.html - не пройденных запросов : 150
# https://auto.drom.ru/rostov-na-donu/lexus/tx350/110619019.html - не пройденных запросов : 150
# https://auto.drom.ru/tomsk/mercedes-benz/mercedes/556087257.html - не пройденных запросов : 150
# https://auto.drom.ru/tomsk/toyota/corolla/746669572.html - не пройденных запросов : 150
# https://auto.drom.ru/ust-uda/uaz/hunter/376226469.html - не пройденных запросов : 150
# https://auto.drom.ru/moscow/cheryexeed/txl/872882971.html - не пройденных запросов : 150
# Thread:52 10/875, https://auto.drom.ru/region72/geely/ck/?ph=1&unsold=1 , Geely CK Otaka, Тюменская область , pages: 1  ads:2
# https://auto.drom.ru/tashtagol/lexus/rx350/728835928.html - не пройденных запросов : 150
# https://auto.drom.ru/vladivostok/mercedes-benz/g-class/834895743.html - не пройденных запросов : 150
# https://auto.drom.ru/ulan-ude/ford/focus/903529689.html - не пройденных запросов : 150
# Обработка https://auto.drom.ru/region59/lexus/rx300/?ph=1&unsold=1, Thread: 18
# Thread:34 20/876, https://auto.drom.ru/region11/renault/megane/?ph=1&unsold=1 , Renault Megane, Республика Коми , pages: 1  ads:2
# Обработка https://auto.drom.ru/region38/ravon/gentra/?ph=1&unsold=1, Thread: 10
# Thread:18 10/876, https://auto.drom.ru/region59/lexus/rx300/?ph=1&unsold=1 , Lexus RX300, Пермский край , pages: 1  ads:3
# Обработка https://auto.drom.ru/region86/nissan/terrano/?ph=1&unsold=1, Thread: 51
# Thread:32 30/876, https://auto.drom.ru/region61/lexus/tx350/?ph=1&unsold=1 , Lexus TX350, Ростовская область , pages: 1  ads:2
# Thread:26 20/876, https://auto.drom.ru/region77/lada/21099/?ph=1&unsold=1 , Лада 21099, Москва , pages: 2  ads:28
# Обработка https://auto.drom.ru/region26/mini/clubman/?ph=1&unsold=1, Thread: 54
# https://auto.drom.ru/tuymazy/geely/emgrand/337864957.html - не пройденных запросов : 150
# Обработка https://auto.drom.ru/region32/lada/2114/?ph=1&unsold=1, Thread: 8
# Thread:10 20/876, https://auto.drom.ru/region38/ravon/gentra/?ph=1&unsold=1 , Ravon Gentra, Иркутская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region58/chevrolet/lacetti/?ph=1&unsold=1, Thread: 29
# Thread:43 20/876, https://auto.drom.ru/region18/mitsubishi/outlander/?ph=1&unsold=1 , Mitsubishi Outlander, Удмуртская Республика , pages: 1  ads:18
# Thread:54 30/875, https://auto.drom.ru/region26/mini/clubman/?ph=1&unsold=1 , MINI Clubman, Ставропольский край , pages: 1  ads:1
# Обработка https://auto.drom.ru/region28/suzuki/jimny/?ph=1&unsold=1, Thread: 14
# Обработка https://auto.drom.ru/region61/faw/bestune_t99/?ph=1&unsold=1, Thread: 35
# Thread:5 30/876, https://auto.drom.ru/region22/mazda/verisa/?ph=1&unsold=1 , Mazda Verisa, Алтайский край , pages: 1  ads:3
# Обработка https://auto.drom.ru/region77/toyota/camry/?ph=1&unsold=1, Thread: 24
# Thread:21 20/876, https://auto.drom.ru/region77/nissan/juke/?ph=1&unsold=1 , Nissan Juke, Москва , pages: 6  ads:106
# Thread:40 30/876, https://auto.drom.ru/region19/honda/freed_spike/?ph=1&unsold=1 , Honda Freed Spike, Республика Хакасия , pages: 2  ads:23
# Обработка https://auto.drom.ru/region46/uaz/patriot/?ph=1&unsold=1, Thread: 25
# Обработка https://auto.drom.ru/region77/gaz/21_volga/?ph=1&unsold=1, Thread: 19
# Обработка https://auto.drom.ru/region16/lada/kalina_cross/?ph=1&unsold=1, Thread: 35
# Обработка https://auto.drom.ru/region36/citroen/c4/?ph=1&unsold=1, Thread: 3
# Обработка https://auto.drom.ru/region86/mitsubishi/pajero_io/?ph=1&unsold=1, Thread: 52
# Thread:25 10/876, https://auto.drom.ru/region46/uaz/patriot/?ph=1&unsold=1 , УАЗ Патриот, Курская область , pages: 1  ads:4
# Thread:19 20/876, https://auto.drom.ru/region77/gaz/21_volga/?ph=1&unsold=1 , ГАЗ 21 Волга, Москва , pages: 1  ads:5
# Thread:6 20/876, https://auto.drom.ru/region41/toyota/carina/?ph=1&unsold=1 , Toyota Carina, Камчатский край , pages: 2  ads:21
# Thread:52 20/875, https://auto.drom.ru/region86/mitsubishi/pajero_io/?ph=1&unsold=1 , Mitsubishi Pajero iO, Ханты-Мансийский автономный округ , pages: 1  ads:1
# Обработка https://auto.drom.ru/region44/chevrolet/aveo/?ph=1&unsold=1, Thread: 22
# Обработка https://auto.drom.ru/region60/tagaz/tager/?ph=1&unsold=1, Thread: 41
# Обработка https://auto.drom.ru/region78/belgee/x70/?ph=1&unsold=1, Thread: 50
# Thread:35 40/876, https://auto.drom.ru/region16/lada/kalina_cross/?ph=1&unsold=1 , Лада Калина Кросс, Республика Татарстан , pages: 1  ads:11
# Thread:41 20/876, https://auto.drom.ru/region60/tagaz/tager/?ph=1&unsold=1 , ТагАЗ Тагер, Псковская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region24/nissan/laurel/?ph=1&unsold=1, Thread: 29
# Thread:3 30/876, https://auto.drom.ru/region36/citroen/c4/?ph=1&unsold=1 , Citroen C4, Воронежская область , pages: 1  ads:18
# Обработка https://auto.drom.ru/region34/peugeot/408/?ph=1&unsold=1, Thread: 10
# Обработка https://auto.drom.ru/region31/great_wall/hover_h5/?ph=1&unsold=1, Thread: 7
# Обработка https://auto.drom.ru/region22/peugeot/partner/?ph=1&unsold=1, Thread: 9
# Обработка https://auto.drom.ru/region33/lexus/gx470/?ph=1&unsold=1, Thread: 14
# Thread:7 30/876, https://auto.drom.ru/region31/great_wall/hover_h5/?ph=1&unsold=1 , Great Wall Hover H5, Белгородская область , pages: 1  ads:1
# Thread:22 20/876, https://auto.drom.ru/region44/chevrolet/aveo/?ph=1&unsold=1 , Chevrolet Aveo, Костромская область , pages: 1  ads:11
# Обработка https://auto.drom.ru/region19/toyota/sai/?ph=1&unsold=1, Thread: 36
# Thread:36 40/876, https://auto.drom.ru/region19/toyota/sai/?ph=1&unsold=1 , Toyota Sai, Республика Хакасия , pages: 1  ads:1
# https://auto.drom.ru/spb/belgee/x70/909718386.html - не пройденных запросов : 150
# Обработка https://auto.drom.ru/region34/chery/qq6_s21/?ph=1&unsold=1, Thread: 12
# Thread:12 20/876, https://auto.drom.ru/region34/chery/qq6_s21/?ph=1&unsold=1 , Chery QQ6 S21, Волгоградская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region42/bmw/i3/?ph=1&unsold=1, Thread: 13
# Обработка https://auto.drom.ru/region50/ssang_yong/musso/?ph=1&unsold=1, Thread: 20
# Thread:34 30/876, https://auto.drom.ru/region2/toyota/land_cruiser_prado/?ph=1&unsold=1 , Toyota Land Cruiser Prado, Республика Башкортостан , pages: 3  ads:51
# Thread:20 20/876, https://auto.drom.ru/region50/ssang_yong/musso/?ph=1&unsold=1 , SsangYong Musso, Московская область , pages: 1  ads:1
# Thread:13 20/876, https://auto.drom.ru/region42/bmw/i3/?ph=1&unsold=1 , BMW i3, Кемеровская область , pages: 1  ads:2
# Обработка https://auto.drom.ru/region5/ford/granada/?ph=1&unsold=1, Thread: 37
# Thread:37 30/876, https://auto.drom.ru/region5/ford/granada/?ph=1&unsold=1 , Ford Granada, Республика Дагестан , pages: 1  ads:1
# Thread:56 20/875, https://auto.drom.ru/region70/chevrolet/lanos/?ph=1&unsold=1 , Chevrolet Lanos, Томская область , pages: 1  ads:15
# Обработка https://auto.drom.ru/region7/datsun/on-do/?ph=1&unsold=1, Thread: 14
# Обработка https://auto.drom.ru/region55/nissan/laurel/?ph=1&unsold=1, Thread: 15
# Thread:14 50/876, https://auto.drom.ru/region7/datsun/on-do/?ph=1&unsold=1 , Datsun on-DO, Кабардино-Балкарская Республика , pages: 1  ads:1
# Thread:15 30/876, https://auto.drom.ru/region55/nissan/laurel/?ph=1&unsold=1 , Nissan Laurel, Омская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region3/uaz/469/?ph=1&unsold=1, Thread: 31
# Обработка https://auto.drom.ru/region35/datsun/on-do/?ph=1&unsold=1, Thread: 12
# Обработка https://auto.drom.ru/region28/honda/n-box/?ph=1&unsold=1, Thread: 6
# Thread:31 30/876, https://auto.drom.ru/region3/uaz/469/?ph=1&unsold=1 , УАЗ 469, Республика Бурятия , pages: 1  ads:4
# Обработка https://auto.drom.ru/region56/toyota/aqua/?ph=1&unsold=1, Thread: 19
# Обработка https://auto.drom.ru/region101/gaz/67/?ph=1&unsold=1, Thread: 9
# Обработка https://auto.drom.ru/region4/toyota/fj_cruiser/?ph=1&unsold=1, Thread: 32
# Thread:6 40/876, https://auto.drom.ru/region28/honda/n-box/?ph=1&unsold=1 , Honda N-BOX, Амурская область , pages: 1  ads:2
# Обработка https://auto.drom.ru/
# Thread:25 810/876, https://auto.drom.ru/region56/haval/f7/?ph=1&unsold=1 , Haval F7, Оренбургская область , pages: 3  ads:49
# Обработка https://auto.drom.ru/region52/izh/2125/?ph=1&unsold=1, Thread: 25
# Thread:25 820/876, https://auto.drom.ru/region52/izh/2125/?ph=1&unsold=1 , ИЖ 2125 Комби, Нижегородская область , pages: 1  ads:1
# Thread:19 780/876, https://auto.drom.ru/region77/hyundai/creta/?ph=1&unsold=1 , Hyundai Creta, Москва , pages: 12  ads:222
# Обработка https://auto.drom.ru/region44/chevrolet/viva/?ph=1&unsold=1, Thread: 19
# Thread:19 790/876, https://auto.drom.ru/region44/chevrolet/viva/?ph=1&unsold=1 , Chevrolet Viva, Костромская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region77/toyota/probox/?ph=1&unsold=1, Thread: 19
# Thread:19 800/876, https://auto.drom.ru/region77/toyota/probox/?ph=1&unsold=1 , Toyota Probox, Москва , pages: 1  ads:2
# Обработка https://auto.drom.ru/region51/chery/tiggo_7_pro_max/?ph=1&unsold=1, Thread: 16
# Обработка https://auto.drom.ru/region52/audi/a4/?ph=1&unsold=1, Thread: 28
# Thread:28 850/876, https://auto.drom.ru/region52/audi/a4/?ph=1&unsold=1 , Audi A4, Нижегородская область , pages: 1  ads:15
# Обработка https://auto.drom.ru/region54/mazda/cx-5/?ph=1&unsold=1, Thread: 18
# Обработка https://auto.drom.ru/region46/honda/jazz/?ph=1&unsold=1, Thread: 19
# Thread:19 810/876, https://auto.drom.ru/region46/honda/jazz/?ph=1&unsold=1 , Honda Jazz, Курская область , pages: 1  ads:1
# Thread:18 740/876, https://auto.drom.ru/region54/mazda/cx-5/?ph=1&unsold=1 , Mazda CX-5, Новосибирская область , pages: 6  ads:108
# Обработка https://auto.drom.ru/region50/vortex/estina/?ph=1&unsold=1, Thread: 28
# Thread:28 860/876, https://auto.drom.ru/region50/vortex/estina/?ph=1&unsold=1 , Vortex Estina, Московская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region77/tesla/model_y/?ph=1&unsold=1, Thread: 18
# Thread:18 750/876, https://auto.drom.ru/region77/tesla/model_y/?ph=1&unsold=1 , Tesla Model Y, Москва , pages: 1  ads:12
# Обработка https://auto.drom.ru/region50/suzuki/jimny/?ph=1&unsold=1, Thread: 18
# Thread:18 760/876, https://auto.drom.ru/region50/suzuki/jimny/?ph=1&unsold=1 , Suzuki Jimny, Московская область , pages: 1  ads:6
# Обработка https://auto.drom.ru/region23/lexus/gx550/?ph=1&unsold=1, Thread: 18
# Thread:18 770/876, https://auto.drom.ru/region23/lexus/gx550/?ph=1&unsold=1 , Lexus GX550, Краснодарский край , pages: 1  ads:2
# Thread:16 820/876, https://auto.drom.ru/region51/chery/tiggo_7_pro_max/?ph=1&unsold=1 , Chery Tiggo 7 Pro Max, Мурманская область , pages: 5  ads:81
# Обработка https://auto.drom.ru/region52/lada/largus_cross/?ph=1&unsold=1, Thread: 19
# Обработка https://auto.drom.ru/region54/lexus/ls460l/?ph=1&unsold=1, Thread: 16
# Thread:16 830/876, https://auto.drom.ru/region54/lexus/ls460l/?ph=1&unsold=1 , Lexus LS460L, Новосибирская область , pages: 1  ads:6
# Thread:18 830/876, https://auto.drom.ru/region77/nissan/sylphy/?ph=1&unsold=1 , Nissan Sylphy, Москва , pages: 1  ads:5
# Обработка https://auto.drom.ru/region59/renault/scenic/?ph=1&unsold=1, Thread: 16
# Thread:16 850/876, https://auto.drom.ru/region59/renault/scenic/?ph=1&unsold=1 , Renault Scenic, Пермский край , pages: 1  ads:4
# Обработка https://auto.drom.ru/region24/toyota/picnic/?ph=1&unsold=1, Thread: 16
# Thread:16 860/876, https://auto.drom.ru/region24/toyota/picnic/?ph=1&unsold=1 , Toyota Picnic, Красноярский край , pages: 1  ads:2
# Обработка https://auto.drom.ru/region77/peugeot/408/?ph=1&unsold=1, Thread: 16
# Thread:16 870/876, https://auto.drom.ru/region77/peugeot/408/?ph=1&unsold=1 , Peugeot 408, Москва , pages: 2  ads:22
# Обработка https://auto.drom.ru/region55/honda/edix/?ph=1&unsold=1, Thread: 18
# Thread:18 840/876, https://auto.drom.ru/region55/honda/edix/?ph=1&unsold=1 , Honda Edix, Омская область , pages: 1  ads:3
# Обработка https://auto.drom.ru/region25/renault/kangoo/?ph=1&unsold=1, Thread: 18
# Thread:18 850/876, https://auto.drom.ru/region25/renault/kangoo/?ph=1&unsold=1 , Renault Kangoo, Приморский край , pages: 1  ads:2
# Обработка https://auto.drom.ru/region25/acura/mdx/?ph=1&unsold=1, Thread: 18
# Thread:18 860/876, https://auto.drom.ru/region25/acura/mdx/?ph=1&unsold=1 , Acura MDX, Приморский край , pages: 1  ads:2
# Обработка https://auto.drom.ru/region77/jeep/grand_cherokee/?ph=1&unsold=1, Thread: 18
# Thread:18 870/876, https://auto.drom.ru/region77/jeep/grand_cherokee/?ph=1&unsold=1 , Jeep Grand Cherokee, Москва , pages: 6  ads:109
# Обработка https://auto.drom.ru/region24/renault_samsung/qm3/?ph=1&unsold=1, Thread: 25
# Thread:25 830/876, https://auto.drom.ru/region24/renault_samsung/qm3/?ph=1&unsold=1 , Renault Samsung QM3, Красноярский край , pages: 1  ads:1
# Обработка https://auto.drom.ru/region23/mazda/mazda5/?ph=1&unsold=1, Thread: 25
# Thread:25 840/876, https://auto.drom.ru/region23/mazda/mazda5/?ph=1&unsold=1 , Mazda Mazda5, Краснодарский край , pages: 1  ads:7
# Обработка https://auto.drom.ru/region51/chrysler/300m/?ph=1&unsold=1, Thread: 25
# Thread:25 850/876, https://auto.drom.ru/region51/chrysler/300m/?ph=1&unsold=1 , Chrysler 300M, Мурманская область , pages: 1  ads:1
# Обработка https://auto.drom.ru/region24/renault/sandero_stepway/?ph=1&unsold=1, Thread: 25
# Thread:25 860/876, https://auto.drom.ru/region24/renault/sandero_stepway/?ph=1&unsold=1 , Renault Sandero Stepway, Красноярский край , pages: 2  ads:31
# Обработка https://auto.drom.ru/region25/subaru/brz/?ph=1&unsold=1, Thread: 25
# Thread:25 870/876, https://auto.drom.ru/region25/subaru/brz/?ph=1&unsold=1 , Subaru BRZ, Приморский край , pages: 1  ads:1
# Предобработка данных
# Сохранение
