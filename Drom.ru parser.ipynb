# %%
import requests as r
import pandas as pd
from IPython.display import clear_output
from bs4 import BeautifulSoup
import time
import random
import urllib3
import urllib
import os
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
import re
from numpy import random, array_split
from multiprocessing.pool import ThreadPool
desktop_agents = ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/602.2.14 (KHTML, like Gecko) Version/10.0.1 Safari/602.2.14',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'
                 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.135 YaBrowser/21.6.3.757 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.164 YaBrowser/21.6.4.786 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 OPR/74.0.3911.107',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.2 Safari/605.1.15',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.18 Safari/537.36 OPR/55.0.2962.0 (Edition developer)',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.152 YaBrowser/21.2.2.102 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.135 YaBrowser/21.6.2.855 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 YaBrowser/20.12.3.138 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 YaBrowser/20.8.3.112 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3343.4 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.170 Safari/537.36 OPR/53.0.2907.68',
                 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0.2 Safari/605.1.15',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 YaBrowser/20.8.2.92 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36 OPR/73.0.3856.344',
                 'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201',
                 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:59.0) Gecko/20100101 Firefox/59.0',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 OPR/74.0.3911.160',
                 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36 Edg/87.0.664.60',
                 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.101 YaBrowser/20.7.0.899 Yowser/2.5 Safari/537.36',
                 'Mozilla/5.0 (Windows NT 6.1; ) AppleWebKit/53']

# %%
def beautiful_html(resp):
    return BeautifulSoup(resp.text,"html.parser")

# %%
def get_regions():
    u=0
    while u==0:
        try:
            raw_data=r.get("https://www.drom.ru/my_region/",proxies=urllib.request.getproxies(),headers={"User-Agent":random.choice(desktop_agents)},verify=False)
            data=beautiful_html(raw_data)
            regions=[]
            for link in data.find_all('a',{'class':'b-link regionLink'},href=True):
                regions.append((link.text.strip(),re.search('=(.+)',link['href']).group(1)))
            u=1
        except:
            time.sleep(60)            
    print("Регионы собраны")
    return regions

# %%
def get_models(tuples):
    print(f"Info about models in all regions. Thread {tuples[0]}")
    model_hrefs=[]
    with r.Session() as s:
        for tup in tuples[1]:
            to=0
            u=0
            length=0
            while u==0:
                try:
                    raw_data=s.get(f"https://auto.drom.ru/region{int(tup[1])}/?grouping=1&ph=1&unsold=1#tabs",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                    data=beautiful_html(raw_data)
                    if raw_data.reason=='OK': 
                        distinct_models=int(re.findall('.+?(?=модел)',data.find_all('a',{'type':'button',"href":f"https://auto.drom.ru/region{int(tup[1])}/?grouping=1&ph=1&unsold=1#tabs"})[0].text.replace('\xa0',u' '))[0].replace(' ',''))
                        number_of_pages=distinct_models//20
                        if  (distinct_models - number_of_pages*20)>0:
                            number_of_pages+=1
                        u=1
                    else:
                        print(f"Thread-{tuples[0]},{tup[1]},не подходящий ответ")
                        to+=1
                        if to%150==0:
                            time.sleep(7)
                        else:
                            time.sleep(3)
                   
                except:
                    print(f"Thread-{tuples[0]}, {tup[1]} ,не удался get запрос")
                    to+=1
                    if to%150==0:
                        time.sleep(7)
                    else:
                        time.sleep(3)
            u=0
            page=1
            to=0
            try:
                while page<=number_of_pages:
                    u=0
                    while u==0:
                        try:
                            raw_data=s.get(f"https://auto.drom.ru/region{int(tup[1])}/page{int(page)}/?grouping=1&ph=1&unsold=1",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                            data=beautiful_html(raw_data)
                            if len(data.find_all('div',{"data-app-root":"bulls-list-models-range"})[0].find_all('a',{'class':"css-ew3ldr esy1m7g5"},href=True))==0:
                                to+=1
                                print(f"Thread-{tuples[0]} , {f'https://auto.drom.ru/region{int(tup[1])}/page{int(page)}/?grouping=1&ph=1&unsold=1'} ,нет ссылок")
                                if to%150==0:
                                    time.sleep(7)
                                else:
                                    time.sleep(3)
                            else:
                               
                                u=1
                        except:
                            print(f"Thread-{tuples[0]} , {f'https://auto.drom.ru/region{int(tup[1])}/page{int(page)}/?grouping=1&ph=1&unsold=1'} ,не удался get запрос")
                            to+=1
                            if to%150==0:
                                time.sleep(7)
                            else:
                                time.sleep(3)
                    hrefs=[(i['href'],re.findall('.+?(?=,)',i.text)[0],tup[0],tup[1]) for i in data.find_all('div',{"data-app-root":"bulls-list-models-range"})[0].find_all('a',{'class':"css-ew3ldr esy1m7g5"},href=True)]
                    for val in hrefs:
                        model_hrefs.append(val)
                    length+=len(hrefs)
                    page+=1
                print(f"{tup[1]},{tup[0]},pages: {number_of_pages}  models: {length} ")
            except:
                print(f"Thread-{tuples[0]} , {tup[0]} ,не удалось перейти по ссылке")
                print(f"{tup[1]},{tup[0]}")
    model_hrefs=set(model_hrefs)
    return model_hrefs

# %%
def get_ad_info(tuples):
    #print(f"Collecting all ads hrefs.Thread {tuples[0]}")
    ads_info=[]
    with r.Session() as s:
        for ind,tup in enumerate(tuples[1]):
            u=0
            to=0
            region_code=tup[-1]
            region=tup[-2]
            model=tup[-3]
            while u==0:
                try:
                    raw_data=s.get(f"{tup[0]}",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                    data=beautiful_html(raw_data)
                    if 'Запрошенная вами страница не существует!' in raw_data.text:
                        break
                    elif 'Подать объявление' not in raw_data.text:
                        raise Exception   
                    elif len([i.text.replace("\xa0"," ") for i in data.find_all("table",{"class":"css-xalqz7 eppj3wm0"})[0].find_all("td",{"class":"css-1la7f7n ezjvm5n0"})])>0: 
                        u=1
                    else:
                        to+=1
                        if to%150==0:
                            time.sleep(7)
                            print(f"{tup[0]} - не пройденных запросов : {to} ")
                        else:
                            time.sleep(3)
                except:
                    to+=1
                    if to%150==0:
                        time.sleep(7)
                        print(f"{tup[0]} - не пройденных запросов : {to} ")
                    else:
                        time.sleep(3)
                
            p=0
            try:
                l2=[i.text.replace("\xa0"," ") for i in data.find_all("table",{"class":"css-xalqz7 eppj3wm0"})[0].find_all('th',{'class':'css-a4bpk4 ezjvm5n1'})]
                l1=[i.text.replace("\xa0"," ") for i in data.find_all("table",{"class":"css-xalqz7 eppj3wm0"})[0].find_all('td',{'class':'css-1la7f7n ezjvm5n0'})]
            except:
                print(f"{tup[0]} - невалидная ссылка. {raw_data.reason}")
#                print(raw_data.text)
#                print(raw_data)
#                print(data)
                p=1
            if p==0:
                dct=dict(zip(l2,l1))
                city=data.find_all("div",{"class":"css-inmjwf e162wx9x0"})[-1].text
                idd=re.search("\/(\d+).html",tup[0]).group(1)
                ads_info.append((region,model,region_code,idd,city,dct))
            #print(f"Thread: {tuples[0]}, {ind+1}/{len(tuples[1])}")
    return ads_info

# %%
def models_exists(data):
    try:
        k=re.findall(".+?(?= объяв)",data.find_all("div",{"class":"css-nlq3fc edzrckn0","id":"tabs"})[0].text)[0].replace('\xa0',u' ').replace(' ','')
        return 1
    except:
        return -1

# %%
def get_ads_hrefs(tuples):
    print(f"Collecting all ads hrefs.Thread {tuples[0]}")
    region=[]
    model=[]
    region_code=[]
    idc=[]
    city=[]
    engine=[]
    power=[]
    transmission=[]
    drive=[]
    body_type=[]
    color=[]
    mileage=[]
    swheel=[]
    
    dupl=0
    with r.Session() as s:
        for ind,tup in enumerate(tuples[1]):
            print(f"Обработка {tup[0]}, Thread: {tuples[0]}")
            to=0
            u=0
            length=0
            while u==0:
                try:
                    raw_data=s.get(f"{tup[0]}",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                    data=beautiful_html(raw_data)
                    p=models_exists(data)
                    if ('Запрошенная вами страница не существует!' in raw_data.text):
                        number_of_pages=0
                        break
                    if raw_data.reason=='OK' and p==1: 
                        distinct_ads=int(re.findall(".+?(?= объяв)",data.find_all("div",{"class":"css-nlq3fc edzrckn0","id":"tabs"})[0].text)[0].replace('\xa0',u' ').replace(' ',''))
                        number_of_pages=distinct_ads//20
                        if  (distinct_ads - number_of_pages*20)>0:
                            number_of_pages+=1
                        u=1
                    elif 'Подать объявление' not in raw_data.text:
                        raise Exception
                    elif p==-1:
                        number_of_pages=0
                        break
                    else:
                        to+=1
                        if to%150==0:
                            print(f"{tup[0]} не пройденных запросов : {to} ")
                            time.sleep(7)
                        else:
                            time.sleep(3)
                except:
                    to+=1
                    if to%150==0:
                        print(f"{tup[0]} не пройденных запросов : {to} ")
                        time.sleep(7)
                    else:
                        time.sleep(3)
            u=0
            page=1
            to=0
            try:
                while page<=number_of_pages:
                    u=0
                    while u==0:
                        try:
                            raw_data=s.get(f"{tup[0].replace('?ph=1&unsold=1','')}page{page}/?unsold=1&ph=1",headers={"User-Agent":random.choice(desktop_agents)},verify=False)
                            data=beautiful_html(raw_data)
                            m=models_exists(data)
                            if ('Запрошенная вами страница не существует!' in raw_data.text):
                                break
                            elif 'Подать объявление' not in raw_data.text:
                                raise Exception
                            elif m==-1:
                                break
                            else:
                                u=1
                        except:
                            to+=1
                            if to%150==0:
                                time.sleep(7)
                                print(f"{tup[0].replace('?ph=1&unsold=1','')}page{page}/?unsold=1&ph=1 - не пройденных запросов: {to}")
                            else:
                                time.sleep(3)
                    if m==1:
                        hrefs=[(i['href'],tup[0],tup[1],tup[2],tup[3]) for i in data.find_all("div",{"data-bulletin-list":"true"})[0].find_all("a",{"class":"css-4zflqt e1huvdhj1"})]
                        length+=len(hrefs)
                        for val in hrefs:
                            i=(val,get_ad_info((1,[val])))
                            if dupl==0:
                                try:
                                    region.append(i[1][0][0])
                                except:
                                    region.append('No info')
                                try:
                                    model.append(i[1][0][1])
                                except:
                                    model.append('No info')
                                try:
                                    region_code.append(i[1][0][2])
                                except:
                                    region_code.append('No info')
                                try:
                                    idc.append(i[1][0][3])
                                except:
                                    idc.append('No info')
                                try:
                                    city.append(i[1][0][4])
                                except:
                                    city.append('No info')
                                try:
                                    engine.append(i[1][0][5]['Двигатель'])
                                except:
                                    engine.append('No info')
                                try:
                                    power.append(i[1][0][5]['Мощность'])
                                except:
                                    power.append('No info')
                                try:
                                    transmission.append(i[1][0][5]['Коробка передач'])
                                except:
                                    transmission.append('No info')
                                try:
                                    drive.append(i[1][0][5]['Привод'])
                                except:
                                    drive.append('No info')
                                try:
                                    body_type.append(i[1][0][5]['Тип кузова'])
                                except:
                                    body_type.append('No info')
                                try:
                                    color.append(i[1][0][5]['Цвет'])
                                except:
                                    color.append('No info')
                                try:
                                    mileage.append(i[1][0][5]['Пробег'])
                                except:
                                    mileage.append('No info')
                                try:
                                    swheel.append(i[1][0][5]['Руль'])
                                except:
                                    swheel.append('No info')
                            else:
                                pass
                    page+=1
                print(f"Thread:{tuples[0]} {ind+1}/{len(tuples[1])}, {tup[0]} , {tup[1]}, {tup[2]} , pages: {number_of_pages}  ads:{length} ")
            except:
                print(f"Thread:{tuples[0]} {ind+1}/{len(tuples[1])}")
                pass
    return pd.DataFrame([idc,region,region_code,city,model,body_type,color,swheel,mileage,engine,power,transmission,drive]).T

# %%
def extract_city(city):
    try:
        return re.findall('Город:([-\sа-яА-Я\d]+)',city)[0].strip()
    except:
        return city
    
def extract_brand(name):
    try:
        return re.findall('^([А-Яа-яA-Za-z]+)',name)[0].replace('Great','Great Wall')
    except:
        return name

def extract_mileage(mil):
    try:
        return int(re.findall('([\s0-9]+) км',mil)[0].replace(' ',''))
    except:
        return mil
    
def extract_HP(val):
    try:
        return int(re.findall('([0-9]+) л.с.,',val)[0])
    except:
        return val

def correct_errors(val):
    if val=='Iran':
        return 'Iran Khodro'
    elif val=='KG':
        return 'KG Mobility'
    elif val=='Land':
        return 'Land Rover'
    elif val=='M':
        return 'M-Hero'
    elif val=='No':
        return 'No info'
    elif val=='Rolls':
        return 'Rolls Royce'
    else:
        return val

# %%
def Drom_Parser():
    regs=get_regions()
    threads_models=8
    rows_divided=list(array_split(regs,threads_models))
    nums_models=[i+1 for i in range(threads_models)]
    rd=list(zip(nums_models,rows_divided))
    pool=ThreadPool(threads_models)
    l=pool.map(get_models,rd)
    hrefs=[]
    for val in l:
        for val_val in val:
            hrefs.append(val_val) 
        threads_ads=55
    rows_divided=list(array_split(hrefs,threads_ads))
    nums_ads=[i+1 for i in range(threads_ads)]
    hd=list(zip(nums_ads,rows_divided))
    pool=ThreadPool(threads_ads)
    l=pool.map(get_ads_hrefs,hd)
    df=pd.concat(l)
    print('Предобработка данных')
    df.columns=['ID','Region','Region code','City','Model','Body type','Color','Steering wheel','Mileage','Engine','Horse power','Transmission','Drive']
    df['City']=df['City'].map(lambda x:extract_city(x))
    df['Brand']=df.Model.map(lambda x:extract_brand(x))
    df['Brand']=df.Brand.map(lambda x:correct_errors(x))
    df['Mileage']=df.Mileage.map(lambda x:extract_mileage(x))
    df['Horse power']=df['Horse power'].map(lambda x:extract_HP(x))
    print('Сохранение')
    df.to_excel("Drom_Scraping_Results.xlsx",sheet_name='Drom Scraping Results')
# Out:
# Регионы собраны
# Info about models in all regions. Thread 1
# Info about models in all regions. Thread 2
# Info about models in all regions. Thread 3
# Info about models in all regions. Thread 4
# Info about models in all regions. Thread 5
# Info about models in all regions. Thread 6
# Info about models in all regions. Thread 7Info about models in all regions. Thread 8
#
# Thread-4, 52 ,не удался get запрос
# Thread-3, 23 ,не удался get запрос
# Thread-1 , https://auto.drom.ru/region22/page2/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-5 , https://auto.drom.ru/region4/page2/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-6 , https://auto.drom.ru/region13/page4/?grouping=1&ph=1&unsold=1 ,не удался get запрос
# Thread-7 , https://auto.drom.ru/region64/page4/?grouping=1&ph=1&unsold=1 ,не удался get запрос
# Thread-3, 23 ,не удался get запрос
# Thread-4 , https://auto.drom.ru/region52/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-5 , https://auto.drom.ru/region4/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3, 23 ,не удался get запрос
# Thread-7 , https://auto.drom.ru/region64/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region18/page10/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3, 23 ,не удался get запрос
# Thread-1 , https://auto.drom.ru/region22/page10/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 13,Республика Мордовия,pages: 11  models: 216
# Thread-2 , https://auto.drom.ru/region101/page14/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region23/page2/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-6 , https://auto.drom.ru/region14/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region23/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-6 , https://auto.drom.ru/region14/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region101/page22/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 4,Республика Алтай,pages: 19  models: 373
# 64,Саратовская область,pages: 22  models: 425
# 18,Удмуртская Республика,pages: 24  models: 472
# Thread-5 , https://auto.drom.ru/region2/page2/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region73/page1/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region52/page28/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 52,Нижегородская область,pages: 31  models: 614
# 65,Сахалинская область,pages: 15  models: 283
# 101,Забайкальский край,pages: 36  models: 701
# Thread-8 , https://auto.drom.ru/region73/page12/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region53/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 14,Республика Саха (Якутия),pages: 26  models: 505
# Thread-5 , https://auto.drom.ru/region2/page19/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 73,Ульяновская область,pages: 15  models: 293
# Thread-5 , https://auto.drom.ru/region2/page20/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-7 , https://auto.drom.ru/region66/page11/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 53,Новгородская область,pages: 9  models: 179
# 15,Республика Северная Осетия,pages: 10  models: 193
# 37,Ивановская область,pages: 13  models: 249
# Thread-7 , https://auto.drom.ru/region66/page11/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-6, 16 ,не удался get запрос
# Thread-5 , https://auto.drom.ru/region2/page26/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 22,Алтайский край,pages: 53  models: 1042
# Thread-4 , https://auto.drom.ru/region54/page9/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-6 , https://auto.drom.ru/region16/page10/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 2,Республика Башкортостан,pages: 37  models: 739
# Thread-2 , https://auto.drom.ru/region38/page26/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-5 , https://auto.drom.ru/region3/page14/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-6 , https://auto.drom.ru/region16/page27/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region27/page43/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 23,Краснодарский край,pages: 70  models: 1381
# 27,Хабаровский край,pages: 43  models: 858
# 16,Республика Татарстан,pages: 35  models: 698
# Thread-1 , https://auto.drom.ru/region28/page26/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 66,Свердловская область,pages: 55  models: 1088
# 3,Республика Бурятия,pages: 34  models: 664
# 28,Амурская область,pages: 35  models: 693
# 67,Смоленская область,pages: 13  models: 252
# Thread-2 , https://auto.drom.ru/region38/page52/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region86/page20/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region29/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 17,Республика Тыва,pages: 16  models: 312
# 54,Новосибирская область,pages: 64  models: 1277
# 38,Иркутская область,pages: 59  models: 1163 Thread-4 , https://auto.drom.ru/region55/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
#
# 5,Республика Дагестан,pages: 15  models: 300
# 29,Архангельская область,pages: 13  models: 254
# Thread-1 , https://auto.drom.ru/region30/page1/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region86/page36/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 6,Республика Ингушетия,pages: 10  models: 189
# 7,Кабардино-Балкарская Республика,pages: 8  models: 146
# Thread-6 , https://auto.drom.ru/region19/page18/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 8,Республика Калмыкия,pages: 2  models: 40
# 86,Ханты-Мансийский автономный округ,pages: 43  models: 851
# Thread-3 , https://auto.drom.ru/region24/page49/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region39/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region55/page24/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 26,Ставропольский край,pages: 33  models: 660
# Thread-1 , https://auto.drom.ru/region30/page16/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region24/page53/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region55/page26/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region39/page13/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 10,Республика Карелия,pages: 13  models: 254
# 30,Астраханская область,pages: 21  models: 407
# 24,Красноярский край,pages: 57  models: 1128
# 39,Калининградская область,pages: 15  models: 294
# 19,Республика Хакасия,pages: 37  models: 735
# 68,Тамбовская область,pages: 13  models: 248
# 11,Республика Коми,pages: 11  models: 202
# Thread-8 , https://auto.drom.ru/region74/page20/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region31/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region74/page23/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-7 , https://auto.drom.ru/region69/page13/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region40/page17/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 40,Калужская область,pages: 18  models: 341
# 55,Омская область,pages: 48  models: 942
# 69,Тверская область,pages: 18  models: 347
# 31,Белгородская область,pages: 20  models: 382
# 45,Курганская область,pages: 28  models: 560
# Thread-8 , https://auto.drom.ru/region74/page34/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-5 , https://auto.drom.ru/region102/page29/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 32,Брянская область,pages: 15  models: 298
# Thread-3 , https://auto.drom.ru/region46/page12/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 41,Камчатский край,pages: 21  models: 407
# Thread-2 , https://auto.drom.ru/region9/page1/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region46/page15/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region33/page5/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 74,Челябинская область,pages: 50  models: 996
# Thread-6 , https://auto.drom.ru/region61/page43/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 56,Оренбургская область,pages: 26  models: 509 46,Курская область,pages: 15  models: 284
#
# Thread-2 , https://auto.drom.ru/region9/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region33/page7/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 61,Ростовская область,pages: 44  models: 879
# Thread-3 , https://auto.drom.ru/region47/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region20/page7/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 9,Карачаево-Черкесская Республика,pages: 5  models: 82
# Thread-1 , https://auto.drom.ru/region33/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region57/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region42/page2/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 102,Республика Крым,pages: 47  models: 928
# Thread-3 , https://auto.drom.ru/region47/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 20,Чеченская Республика,pages: 10  models: 191
# 57,Орловская область,pages: 8  models: 144
# Thread-6 , https://auto.drom.ru/region62/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region47/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-5 , https://auto.drom.ru/region12/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 33,Владимирская область,pages: 14  models: 279
# 70,Томская область,pages: 40  models: 798 47,Ленинградская область,pages: 8  models: 160
#
# Thread-7 , https://auto.drom.ru/region71/page1/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region58/page6/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-5 , https://auto.drom.ru/region12/page10/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-7 , https://auto.drom.ru/region71/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 62,Рязанская область,pages: 16  models: 305
# Thread-5 , https://auto.drom.ru/region12/page10/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region34/page9/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 21,Чувашская Республика,pages: 16  models: 320
# 87,Чукотский автономный округ,pages: 1  models: 6
# 12,Республика Марий Эл,pages: 10  models: 185
# Thread-2 , https://auto.drom.ru/region42/page19/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 58,Пензенская область,pages: 15  models: 293
# 48,Липецкая область,pages: 14  models: 275
# 71,Тульская область,pages: 19  models: 372
# Thread-1 , https://auto.drom.ru/region34/page19/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region42/page30/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 49,Магаданская область,pages: 16  models: 309
# Thread-4 , https://auto.drom.ru/region59/page20/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 89,Ямало-Ненецкий автономный округ,pages: 23  models: 456
# 34,Волгоградская область,pages: 28  models: 558
# Thread-6 , https://auto.drom.ru/region63/page30/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region59/page24/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region76/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 63,Самарская область,pages: 32  models: 635
# Thread-4 , https://auto.drom.ru/region59/page25/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-4 , https://auto.drom.ru/region59/page28/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region35/page15/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-6 , https://auto.drom.ru/region78/page9/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-7 , https://auto.drom.ru/region72/page29/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-6 , https://auto.drom.ru/region78/page9/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 42,Кемеровская область,pages: 54  models: 1064
# 35,Вологодская область,pages: 17  models: 321
# Thread-2, 43 ,не удался get запрос
# Thread-7 , https://auto.drom.ru/region72/page31/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1, 36 ,не удался get запрос
# 59,Пермский край,pages: 33  models: 647
# Thread-1 , https://auto.drom.ru/region36/page4/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-8 , https://auto.drom.ru/region76/page23/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region43/page7/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 76,Ярославская область,pages: 23  models: 443
# Thread-6 , https://auto.drom.ru/region78/page23/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region43/page11/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 72,Тюменская область,pages: 52  models: 1030
# Thread-6 , https://auto.drom.ru/region78/page29/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 43,Кировская область,pages: 19  models: 366
# Thread-1 , https://auto.drom.ru/region36/page23/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region44/page5/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region77/page60/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-1 , https://auto.drom.ru/region36/page26/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-2 , https://auto.drom.ru/region44/page8/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region77/page64/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 44,Костромская область,pages: 8  models: 159 36,Воронежская область,pages: 30  models: 592
#
# Thread-6 , https://auto.drom.ru/region78/page51/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 77,Москва,pages: 71  models: 1403
# 78,Санкт-Петербург,pages: 54  models: 1064
# Thread-3 , https://auto.drom.ru/region50/page3/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 79,Еврейская автономная область,pages: 12  models: 238
# 25,Приморский край,pages: 56  models: 1106
# 60,Псковская область,pages: 12  models: 221
# Thread-4 , https://auto.drom.ru/region1/page7/?grouping=1&ph=1&unsold=1 ,нет ссылок
# Thread-3 , https://auto.drom.ru/region50/page32/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 1,Республика Адыгея,pages: 11  models: 205
# 50,Московская область,pages: 44  models: 862
# Thread-3 , https://auto.drom.ru/region51/page9/?grouping=1&ph=1&unsold=1 ,нет ссылок
# 51,Мурманская область,pages: 14  models: 265
# Thread-3, 83 ,не удался get запрос
# 83,Ненецкий автономный округ,pages: 1  models: 6
